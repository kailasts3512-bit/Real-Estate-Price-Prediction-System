# %% [markdown]
# # Real Estate Price Prediction System
# Industry-Ready Capstone Project

# %% [markdown]
# ## Part 1 - Setup and Data Engineering

# %%
# !pip install -q pandas numpy matplotlib scikit-learn seaborn xgboost lightgbm catboost shap optuna joblib fastapi uvicorn streamlit mlflow evidently ydata-profiling

# %%
import pandas as pd
import numpy as np
print('Environment Ready')

# %% [markdown]
# ## Parts 2-6
# EDA, Modeling, FastAPI, Streamlit, Docker, CI/CD
